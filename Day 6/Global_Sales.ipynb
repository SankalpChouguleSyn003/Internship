# %% [raw]
# This project includes messy data cleaning of Global Sales dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Global_Sales_Messy_Data.csv')

# %%
df.head()
df.tail()
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    1000 non-null   int64
#  1   Transaction_Date  1000 non-null   object
#  2   Server_Timestamp  1000 non-null   object
#  3   Store_Location    1000 non-null   object
#  4   Sales_Amount      1000 non-null   float64
#  5   Currency          1000 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 31.3+ KB

# %%
df.dtypes
# Out:
# Transaction_ID        int64
# Transaction_Date     object
# Server_Timestamp     object
# Store_Location       object
# Sales_Amount        float64
# Currency             object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Transaction_ID      0
# Transaction_Date    0
# Server_Timestamp    0
# Store_Location      0
# Sales_Amount        0
# Currency            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Transaction_Date"] = pd.to_datetime(df["Transaction_Date"], format= "mixed") 
df
# Out:
#      Transaction_ID Transaction_Date           Server_Timestamp  \
# 0              1000       2023-03-09  2023-09-03 02:00:00 +0000
# 1              1001       2023-11-24    2023-11-24 12:00:00 PST
# 2              1002       2023-06-21  2023-06-21 05:00:00 +0000
# 3              1003       2023-11-13    2023-11-13 16:00:00 EST
# 4              1004       2023-07-28  2023-07-28 06:00:00 +0530
# ..              ...              ...                        ...
# 995            1995       2023-01-11           01-11-2023 04:00
# 996            1996       2023-05-28    2023-05-28 00:00:00 UTC
# 997            1997       2023-10-31    2023-10-31 15:00:00 EST
# 998            1998       2023-02-20    2023-02-20 14:00:00 PST
# 999            1999       2023-11-01    2023-01-11 01:00:00 UTC
#
#     Store_Location  Sales_Amount Currency
# 0          ZÃ¼rich        257.52      EUR
# 1       SÃ£o Paulo         81.77      EUR
# 2            Tokyo        326.06      USD
# ...

# %%
from datetime import datetime
df['Server_Timestamp']= pd.to_datetime(df['Server_Timestamp'], format='mixed', utc=True)
df
# Out:
#      Transaction_ID Transaction_Date          Server_Timestamp Store_Location  \
# 0              1000       2023-03-09 2023-09-03 02:00:00+00:00        ZÃ¼rich
# 1              1001       2023-11-24 2023-11-24 12:00:00+00:00     SÃ£o Paulo
# 2              1002       2023-06-21 2023-06-21 05:00:00+00:00          Tokyo
# 3              1003       2023-11-13 2023-11-13 16:00:00+00:00        ZÃ¼rich
# 4              1004       2023-07-28 2023-07-28 00:30:00+00:00      MontrÃ©al
# ..              ...              ...                       ...            ...
# 995            1995       2023-01-11 2023-01-11 04:00:00+00:00     SÃ£o Paulo
# 996            1996       2023-05-28 2023-05-28 00:00:00+00:00        ZÃ¼rich
# 997            1997       2023-10-31 2023-10-31 15:00:00+00:00       MÃ¼nchen
# 998            1998       2023-02-20 2023-02-20 14:00:00+00:00        ZÃ¼rich
# 999            1999       2023-11-01 2023-01-11 01:00:00+00:00         London
#
#      Sales_Amount Currency
# ...

# %%
df['Server_Timestamp']= pd.to_datetime(df['Server_Timestamp']).dt.strftime("%Y-%m-%d %H:%M:%S") + 'UTC' 
df
# Out:
#      Transaction_ID Transaction_Date        Server_Timestamp Store_Location  \
# 0              1000       2023-03-09  2023-09-03 02:00:00UTC        ZÃ¼rich
# 1              1001       2023-11-24  2023-11-24 12:00:00UTC     SÃ£o Paulo
# 2              1002       2023-06-21  2023-06-21 05:00:00UTC          Tokyo
# 3              1003       2023-11-13  2023-11-13 16:00:00UTC        ZÃ¼rich
# 4              1004       2023-07-28  2023-07-28 00:30:00UTC      MontrÃ©al
# ..              ...              ...                     ...            ...
# 995            1995       2023-01-11  2023-01-11 04:00:00UTC     SÃ£o Paulo
# 996            1996       2023-05-28  2023-05-28 00:00:00UTC        ZÃ¼rich
# 997            1997       2023-10-31  2023-10-31 15:00:00UTC       MÃ¼nchen
# 998            1998       2023-02-20  2023-02-20 14:00:00UTC        ZÃ¼rich
# 999            1999       2023-11-01  2023-01-11 01:00:00UTC         London
#
#      Sales_Amount Currency
# 0          257.52      EUR
# ...

# %%
# %pip install ftfy
import ftfy

df['Store_Location'] = df['Store_Location'].apply(ftfy.fix_text)
df = df.apply(lambda col: col.apply(ftfy.fix_text) if col.dtype == 'object' else col)
df.head()
# Out:
#    Transaction_ID Transaction_Date        Server_Timestamp Store_Location  \
# 0            1000       2023-03-09  2023-09-03 02:00:00UTC         Zürich
# 1            1001       2023-11-24  2023-11-24 12:00:00UTC      São Paulo
# 2            1002       2023-06-21  2023-06-21 05:00:00UTC          Tokyo
# 3            1003       2023-11-13  2023-11-13 16:00:00UTC         Zürich
# 4            1004       2023-07-28  2023-07-28 00:30:00UTC       Montréal
#
#    Sales_Amount Currency
# 0        257.52      EUR
# 1         81.77      EUR
# 2        326.06      USD
# 3        240.11      JPY
# 4        169.07      USD

# %%
# %pip install pandas openpyxl
df.to_excel('Cleaned_Global_Sales.xlsx')
