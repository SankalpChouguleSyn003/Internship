# %% [raw]
# This Project includes Regex Operations on Text Scrapping Dataset.

# %%
import pandas as pd
import re

# %%
df = pd.read_csv("Salary_Data.csv")
df
# Out:
#                         Age                      Job_Title    Salary
# 0      32 Male Bachelor's 5              Software Engineer   90000.0
# 1      28 Female Master's 3                   Data Analyst   65000.0
# 2            45 Male PhD 15                 Senior Manager  150000.0
# 3    36 Female Bachelor's 7                Sales Associate   60000.0
# 4       52 Male Master's 20                       Director  200000.0
# ..                      ...                            ...       ...
# 370  35 Female Bachelor's 8       Senior Marketing Analyst   85000.0
# 371     43 Male Master's 19         Director of Operations  170000.0
# 372  29 Female Bachelor's 2         Junior Project Manager   40000.0
# 373    34 Male Bachelor's 7  Senior Operations Coordinator   90000.0
# 374        44 Female PhD 15        Senior Business Analyst  150000.0
#
# [375 rows x 3 columns]

# %%
pattern = r"^\s+$"

# %%
df[["Age", "Gender", "Education_Level", "Years_of_Experience"]] = \
df["Age,Gender,Education Level,Year of Experience"].str.split(pattern, expand=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age,Gender,Education Level,Year of Experience'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 2
# ...

# %%
# Out:
# Index(['Age', 'Job_Title', 'Salary'], dtype='object')
