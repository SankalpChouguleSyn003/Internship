# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Complete_SEDS.csv')

# %%
df.head()
df.tail()
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2364930 entries, 0 to 2364929
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Data_Status  object
#  1   MSN          object
#  2   StateCode    object
#  3   Year         int64
#  4   Data         float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 63.2+ MB
# (2364930, 5)

# %%
df.describe()
# Out:
#                Year          Data
# count  2.364930e+06  2.364930e+06
# mean   1.994216e+03  9.307645e+04
# std    1.791454e+01  1.266106e+06
# min    1.960000e+03 -7.566390e+05
# 25%    1.979000e+03  6.777500e-01
# 50%    1.995000e+03  6.400000e+01
# 75%    2.010000e+03  5.555000e+03
# max    2.023000e+03  1.026705e+08

# %%
df.describe().T
# Out:
#           count          mean           std       min         25%     50%  \
# Year  2364930.0   1994.216350  1.791454e+01    1960.0  1979.00000  1995.0
# Data  2364930.0  93076.448871  1.266106e+06 -756639.0     0.67775    64.0
#
#          75%          max
# Year  2010.0       2023.0
# Data  5555.0  102670531.0

# %%
df.dtypes
# Out:
# Data_Status     object
# MSN             object
# StateCode       object
# Year             int64
# Data           float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Data_Status    0
# MSN            0
# StateCode      0
# Year           0
# Data           0
# dtype: int64

# %%
df['Data'] = pd.to_numeric(df['Data'], errors='coerce')

# %%
df['Year'] = pd.to_datetime, format='%Y'

# %%
df.to_csv('Cleaned_Energy_data.csv', index= True)

# %%
plt.figure()
plt.plot(df.index, df['Data'])
plt.title('Energy Consumption')
plt.xlabel('Year')
plt.ylabel('Consumption')
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(df['Data'], order = (1,1,1))
model_fit = model.fit()

print(model_fit.summary())
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[15], line 3
#       1 from statsmodels.tsa.arima.model import ARIMA
#       2 model = ARIMA(df['Data'], order = (1,1,1))
# ----> 3 model_fit = model.fit()
#       5 print(model_fit.summary())
#
# File /lib/python3.13/site-packages/statsmodels/tsa/arima/model.py:395, in ARIMA.fit(self, start_params, transformed, includes_fixed, method, method_kwargs, gls, gls_kwargs, cov_type, cov_kwds, return_params, low_memory)
#     392 else:
#     393     method_kwargs.setdefault('disp', 0)
# --> 395     res = super().fit(
#     396         return_params=return_params, low_memory=low_memory,
#     397         cov_type=cov_type, cov_kwds=cov_kwds, **method_kwargs)
#     398     if not return_params:
#     399         res.fit_details = res.mlefit
#
# File /lib/python3.13/site-packages/statsmodels/tsa/statespace/mlemodel.py:729, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     727 else:
#     728     func = self.smooth
# --> 729 res = func(mlefit.params, transformed=False, includes_fixed=False,
#     730            cov_type=cov_type, cov_kwds=cov_kwds)
#     732 res.mlefit = mlefit
#     733 res.mle_retvals = mlefit.mle_retvals
#
# File /lib/python3.13/site-packages/statsmodels/tsa/statespace/mlemodel.py:887, in MLEModel.smooth(self, params, transformed, includes_fixed, complex_step, cov_type, cov_kwds, return_ssm, results_class, results_wrapper_class, **kwargs)
#     884     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     886 # Get the state space output
# --> 887 result = self.ssm.smooth(complex_step=complex_step, **kwargs)
#     889 # Wrap in a results object
#     890 return self._wrap_results(params, result, return_ssm, cov_type,
#     891                           cov_kwds, results_class,
#     892                           results_wrapper_class)
#
# File /lib/python3.13/site-packages/statsmodels/tsa/statespace/kalman_smoother.py:423, in KalmanSmoother.smooth(self, smoother_output, smooth_method, results, run_filter, prefix, complex_step, update_representation, update_filter, update_smoother, **kwargs)
#     421 # Update the results
#     422 if update_smoother:
# --> 423     results.update_smoother(smoother)
#     425 return results
#
# File /lib/python3.13/site-packages/statsmodels/tsa/statespace/kalman_smoother.py:676, in SmootherResults.update_smoother(self, smoother)
#     673         setattr(self, name, matrix)
#     674     else:
#     675         setattr(self, name,
# --> 676                 np.array(getattr(smoother, name, None), copy=True))
#     677 else:
#     678     setattr(self, name, None)
#
# MemoryError: Unable to allocate 162. MiB for an array with shape (3, 3, 2364930) and data type float64

# %%
forecast = model.fit.forecast(steps = 10)
print(forecast)
